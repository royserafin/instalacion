# %%
import pandas as pd
import os

# %%
os.listdir()
# Out:
# ['medianas_vr.png',
#  'panoramica2_vr.png',
#  '.DS_Store',
#  'rnped_fuerocomun',
#  'promedio_hombre.png',
#  'promedios_vr.png',
#  'pi-face-recognition',
#  'mediana_mujer1.png',
#  'mediana_mujer.png',
#  'panoramica.png',
#  'ReadMe.md',
#  'panoramica_vr.png',
#  'personasdesaparecidas.json',
#  'mediana_hombre.png',
#  'Imagenes',
#  'promedio_mujer.png',
#  'Procesamiento de caras desaparecidas.ipynb',
#  '.ipynb_checkpoints',
#  '.git',
#  'imagen_promedio.png',
#  'procesamiento de datos desaparecidos.ipynb',
#  'mediana_hombre1.png']

# %%
os.listdir('rnped_fuerocomun')
# Out:
# ['.DS_Store',
#  'rnped_fuerocomun_31_07_17_2.csv',
#  'rnped_fuerocomun_01_12_2017_2.csv',
#  'report_12_01_2018_2.csv']

# %%
df1=pd.read_csv('rnped_fuerocomun/rnped_fuerocomun_31_07_17_2.csv')
df2=pd.read_csv('rnped_fuerocomun/rnped_fuerocomun_01_12_2017_2.csv')
df3=pd.read_csv('rnped_fuerocomun/report_12_01_2018_2.csv')
print(df1.shape,df2.shape,df3.shape)
# Out:
# (32277, 21) (33513, 21) (34441, 22)

# %%
pd.get_dummies(df1['identificado'])
# Out:
#        completo  incompleto  no
# 0             1           0   0
# 1             1           0   0
# 2             1           0   0
# 3             1           0   0
# 4             1           0   0
# 5             1           0   0
# 6             1           0   0
# 7             1           0   0
# 8             1           0   0
# 9             1           0   0
# 10            1           0   0
# 11            1           0   0
# 12            1           0   0
# 13            1           0   0
# 14            1           0   0
# 15            1           0   0
# 16            1           0   0
# 17            1           0   0
# 18            1           0   0
# 19            1           0   0
# 20            1           0   0
# 21            1           0   0
# 22            1           0   0
# 23            1           0   0
# 24            1           0   0
# 25            1           0   0
# 26            1           0   0
# 27            1           0   0
# ...

# %%
df2.head()
# Out:
#    index  prim_nombre seg_nombre apellido_pat apellido_mat  \
# 0    201       DANIEL        NaN        ISLAS      CAZARES
# 1   8026         EMMA        NaN        OCHOA        SOLAR
# 2   8027       ADOLFO        NaN       VARGAS     ZAPOTECO
# 3   8028    MARGARITA        NaN    JARAMILLO      SANCHEZ
# 4   8029  DULCE MARIA        NaN     CASTILLO      BUENDIA
#
#   fuerocomun_complexion  fuerocomun_dependencia fuerocomun_desapentidad  \
# 0               Delgada            FGE - SONORA                  SONORA
# 1               Mediana            FGE - PUEBLA                  PUEBLA
# 2               Robusta          FGE - GUERRERO                GUERRERO
# 3       NO ESPECIFICADO        PGJ - NUEVO LEON              NUEVO LEON
# 4               Delgada  FGJ - ESTADO DE MEXICO        ESTADO DE MEXICO
#
#   fuerocomun_desapfecha fuerocomun_desaphora     ...       \
# 0            01/01/2016             02:00:00     ...
# 1            07/11/2016             09:00:00     ...
# ...

# %%
df3.head()
# Out:
#      prim_nombre seg_nombre apellido_pat apellido_mat fuerocomun_complexion  \
# 0         ALONSO        NaN        JIRON       MENDEZ       NO ESPECIFICADO
# 1  JESUS ANTONIO        NaN      RAMIREZ       FRAIRE               Delgada
# 2       FERNANDO        NaN   DE LA PENA        VITAL               Mediana
# 3          JESUS        NaN     SANDOVAL        ORTIZ               Mediana
# 4       FEDERICO        NaN        LUJAN         DIAZ               Robusta
#
#   fuerocomun_dependencia fuerocomun_desapentidad fuerocomun_desapfecha  \
# 0        FGE - QUERETARO               QUERETARO            01/01/1971
# 1        FGE - CHIHUAHUA               CHIHUAHUA            01/01/1979
# 2        FGE - CHIHUAHUA               CHIHUAHUA            01/01/1997
# 3          FGE - DURANGO                 DURANGO            01/01/1997
# 4        FGE - CHIHUAHUA               CHIHUAHUA            01/01/1997
#
#   fuerocomun_desaphora fuerocomun_desaplocalidad    ...     \
# ...
